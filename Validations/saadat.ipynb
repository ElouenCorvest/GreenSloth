# %% [markdown]
# # Saadat validations

# %%
from mxlbricks import get_saadat2021
from mxlpy import units
import mxlbricks.names as n
import matplotlib.pyplot as plt

m = get_saadat2021()
m.update_reaction(n.rubisco_carboxylase(), unit=units.mmol / (units.liter * units.second)); # Add Vc unit mM/s
file_prepend = "presentation"  # Path to save figures
file_append = "saadat2021"  # Identifier for the model validation

# %%
pfd_str = n.pfd()
vc_str = n.rubisco_carboxylase()
atp_str = n.atp()
nadph_str = n.nadph()
flourescence_str = n.fluorescence()
co2_str = n.co2()
pco2_str = None
H_cp_co2_str = None
gammastar_str = None
r_light_str = None
A_str = None
coeff_psii_str = "k2"
coeff_psi_str = None
coeff_rubisco_str = n.kcat(n.rubisco_carboxylase())
coeff_cytb6f_str = n.kcat(n.b6f())
coeff_atp_synthase_str = n.kf(n.atp_synthase())
rubp_str = n.rubp()
pq_str = n.pq_ox()
pc_str = n.pc_ox()
v_psii_str = "PSII"
v_psi_str = "PSI"
v_cytb6f_str = n.b6f()
v_atp_synthase_str = n.atp_synthase()

# %%
n.kf(n.atp_synthase())
# Out:
# 'kf_atp_synthase'

# %% [markdown]
# ## Day simulation

# %%
from GreenSlothUtils.demonstration import create_day_simulation_fig

fig, ax = create_day_simulation_fig(
    model=m,
    pfd=pfd_str,
    vc=vc_str,
    atp=atp_str,
    nadph=nadph_str,
    flourescence=flourescence_str
)

ax.set_title(file_append)

plt.savefig(f"{file_prepend}/day_simulation/{file_append}.png", dpi=300, bbox_inches='tight')
# Out:
# INFO:root:Downloading 1 NEON DP1.00024.001 files totaling approximately 16.6 MB.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 232.829740557736 and h = 1.9958724885342, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 100 time points per step.
# Trying simulation with 200 time points per step.
# Trying simulation with 300 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 173.787460383441 and h = 1.247328094108, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 30.0217726081648 and h = 0.0134103113270673, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 155.685833837717 and h = 0.140238186440928, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 400 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 228.683912424361 and h = 1.1138971904657, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 138.632059609246 and h = 0.27848304923714, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 500 time points per step.
# Trying simulation with 600 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 164.561315614721 and h = 0.971750940578643, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 700 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 321.443742507336 and h = 0.800300971448427, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 800 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 214.061227164519 and h = 0.213613201929313, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 139.938984842977 and h = 0.693189835189235, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 900 time points per step.
# Trying simulation with 1000 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 175.578504832998 and h = 0.968044994417423, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 1100 time points per step.
# Trying simulation with 1200 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 216.496252367395 and h = 0.59980161192268, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 101.421191485225 and h = 0.0264990536736578, the error test failed repeatedly or with |h| = hmin.
# Trying simulation with 1300 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 174.324002347485 and h = 0.0685333819874842, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 140.201555963093 and h = 0.254787010977115, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 1400 time points per step.
# Trying simulation with 1500 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 178.064194213322 and h = 0.891977856115573, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 1600 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 159.214085433565 and h = 0.853555248271948, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 153.572540399638 and h = 0.16064597972253, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 1700 time points per step.
# Trying simulation with 1800 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 139.14179635291 and h = 0.335404254251242, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 1900 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 139.11744098914 and h = 0.336652426249992, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 2000 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 215.137297512244 and h = 0.828800056996198, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 2100 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 240.30647205104 and h = 0.0201743174043394, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 2200 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 208.901995469237 and h = 0.318836704393548, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 2300 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 218.018806170374 and h = 0.895636281531557, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 2400 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 230.015217094102 and h = 1.31856289839282, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 141.280289871624 and h = 0.340429124355505, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 2500 time points per step.
# Trying simulation with 2600 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 215.63232463655 and h = 0.80977834294832, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 2700 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 140.482147559394 and h = 0.241106651261775, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 139.416693109619 and h = 0.243567499140254, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 2800 time points per step.
# Trying simulation with 2900 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 137.731966669595 and h = 0.164555254783653, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 3000 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 162.493288363348 and h = 0.786296967666186, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 3100 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 224.436548320929 and h = 1.28646196417393, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 140.21917229427 and h = 0.219758353517341, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 3200 time points per step.
# Trying simulation with 3300 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 93.3183137506458 and h = 0.0203658936555292, the error test failed repeatedly or with |h| = hmin.
# Trying simulation with 3400 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 158.151021173076 and h = 0.918110571952726, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 167.551236234648 and h = 0.192531570130637, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 3500 time points per step.
# Trying simulation with 3600 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 234.924765958548 and h = 2.01268499582872, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 3700 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 162.923996470213 and h = 1.17285236748042, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 3800 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 226.677709970244 and h = 0.757888795366979, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 3900 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 171.340375319774 and h = 0.245992027231166, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 93.2218087199679 and h = 0.0204071728171956, the error test failed repeatedly or with |h| = hmin.
# Trying simulation with 4000 time points per step.
# Trying simulation with 4100 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 137.345001693217 and h = 0.61950649969767, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 4200 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 224.049352768874 and h = 0.845645984692754, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 4300 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 226.559730028278 and h = 1.11613653269901, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 4400 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 138.655065414155 and h = 0.281509112851307, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 4500 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 221.484525865507 and h = 0.314559004813487, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 4600 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 137.937861989792 and h = 0.20496444806867, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 134.177486158021 and h = 0.18955884825944, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 4700 time points per step.
# Trying simulation with 4800 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 168.68596415748 and h = 0.125129092535585, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 4900 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 170.936347045069 and h = 0.612943157158482, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 5000 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 139.277278382389 and h = 0.360687990501697, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 5100 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 224.384531445011 and h = 1.14480569335309, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 164.324219202241 and h = 1.04489314671423, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 5200 time points per step.
# Trying simulation with 5300 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 101.537449304966 and h = 0.024093005610425, the error test failed repeatedly or with |h| = hmin.
# Trying simulation with 5400 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 175.004748806586 and h = 1.29630132909805, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 5500 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 138.001608536019 and h = 0.291511545152584, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 177.535819403565 and h = 1.49751061522848, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 5600 time points per step.
# Trying simulation with 5700 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 160.108721536678 and h = 0.563822769502095, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 101.59870511522 and h = 0.0239939246715698, the error test failed repeatedly or with |h| = hmin.
# Trying simulation with 5800 time points per step.
# Trying simulation with 5900 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 171.117791376718 and h = 1.09924125099301, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 6000 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 180.05671348334 and h = 0.00311111912302476, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 6100 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 149.918244702661 and h = 0.0796727679010049, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 6200 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 140.763556172405 and h = 0.342110855334795, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 6300 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 212.290767259257 and h = 0.831390393174419, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 94.8138254178969 and h = 0.0227646097665266, the error test failed repeatedly or with |h| = hmin.
# Trying simulation with 6400 time points per step.
# Trying simulation with 6500 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 140.658361862946 and h = 0.244625682777337, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 89.0033261928542 and h = 0.0174542569850378, the error test failed repeatedly or with |h| = hmin.
# Trying simulation with 6600 time points per step.
# Trying simulation with 6700 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 138.521441777202 and h = 0.243666828044536, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 6800 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 168.306882658295 and h = 1.35608379292786, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 6900 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 219.367272860284 and h = 0.446053957735318, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 7000 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 224.463249955647 and h = 1.28695121687173, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 136.578843047621 and h = 0.228179960321355, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 7100 time points per step.
# Trying simulation with 7200 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 324.263218972457 and h = 0.857339928225803, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 138.647614930898 and h = 0.0979743193607149, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 7300 time points per step.
# Trying simulation with 7400 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 142.219172132484 and h = 0.190592701798351, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 7500 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 139.52617842149 and h = 0.15960854611054, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 7600 time points per step.
# Trying simulation with 7700 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 161.970634057065 and h = 0.493161081886971, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 227.844180310353 and h = 1.109570801487, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 7800 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 136.336752346828 and h = 0.23692166662708, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 142.352763096197 and h = 0.10464882368196, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 7900 time points per step.
# Trying simulation with 8000 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 170.530684788035 and h = 1.2806953570359, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 8100 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 137.858771106695 and h = 0.238146137563407, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 8200 time points per step.
# Trying simulation with 8300 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 138.791762193737 and h = 0.37537453726903, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 168.898290845324 and h = 0.811477208406656, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 8400 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 155.601197230819 and h = 0.233614777302959, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 8500 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 162.218438963475 and h = 0.989522708731462, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 8600 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 162.319603686528 and h = 1.42914414601815, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 8700 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 153.76718205583 and h = 0.85456464582563, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 8800 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 141.173244851485 and h = 0.617390290475383, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 115.634778584423 and h = 1.33846028804046, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 8900 time points per step.
# Trying simulation with 9000 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 136.61190314858 and h = 0.137124387303138, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 9100 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 139.979589703526 and h = 0.497732389779575, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 9200 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 137.737005162536 and h = 0.169095095599078, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 9300 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 138.750200609346 and h = 0.373307591475237, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 9400 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 177.800190975799 and h = 1.37216439479541, the corrector convergence test failed repeatedly or with |h| = hmin.
# Trying simulation with 9500 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 161.185757294264 and h = 0.454972467290067, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 100.155900608842 and h = 0.0240371720529763, the error test failed repeatedly or with |h| = hmin.
# Trying simulation with 9600 time points per step.
# Trying simulation with 9700 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 141.976607753534 and h = 0.282937448963005, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 100.71352739822 and h = 0.0219801877186216, the error test failed repeatedly or with |h| = hmin.
# Trying simulation with 9800 time points per step.
# Trying simulation with 9900 time points per step.
# Trying simulation with 10000 time points per step.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1757353025193/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 138.526374227304 and h = 0.236841438064043, the corrector convergence test failed repeatedly or with |h| = hmin.
# ---------------------------------------------------------------------------
# CVodeError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 from GreenSlothUtils.demonstration import create_day_simulation_fig
# ----> 3 fig, ax = create_day_simulation_fig(
#       4     model=m,
#       5     pfd=pfd_str,
#       6     vc=vc_str,
#       7     atp=atp_str,
#       8     nadph=nadph_str,
#       9     flourescence=flourescence_str
#      10 )
#      12 ax.set_title(file_append)
#      14 plt.savefig(f"{file_prepend}/day_simulation/{file_append}.png", dpi=300, bbox_inches='tight')
#
# File ~/Documents/GreenSlothUtils/src/GreenSlothUtils/demonstration/day_simulation.py:101, in create_day_simulation_fig(model, pfd, vc, atp, nadph, flourescence)
#      97     else:
#      98         res_prior = "done"
# --> 101 res = s.get_result().unwrap_or_err()
#     102 variables = res.get_variables()
#     103 variables.index = pd.to_datetime(
#     104     variables.index, unit="s", origin="2023-06-19 06:00:00"
#     105 )
#
# File ~/Documents/GreenSloth/models/.pixi/envs/default/lib/python3.13/site-packages/mxlpy/types.py:136, in Result.unwrap_or_err(self)
#     134 """Obtain value if Ok, else raise exception."""
#     135 if isinstance(value := self.value, Exception):
# --> 136     raise value
#     137 return value
#
# File ~/Documents/GreenSloth/models/.pixi/envs/default/lib/python3.13/site-packages/mxlpy/integrators/int_assimulo.py:103, in Assimulo.integrate(self, t_end, steps)
#     101     steps = 0
#     102 try:
# --> 103     t, y = self.integrator.simulate(t_end, steps)
#     104     return Result(
#     105         TimeCourse(
#     106             time=np.atleast_1d(np.array(t, dtype=float)),
#     107             values=np.atleast_2d(np.array(y, dtype=float)),
#     108         )
#     109     )
#     110 except CVodeError as e:
#
# File assimulo/ode.pyx:192, in assimulo.ode.ODE.simulate()
#
# File assimulo/ode.pyx:312, in assimulo.ode.ODE.simulate()
#
# File assimulo/explicit_ode.pyx:137, in assimulo.explicit_ode.Explicit_ODE._simulate()
#
# File assimulo/explicit_ode.pyx:222, in assimulo.explicit_ode.Explicit_ODE._simulate()
#
# File assimulo/solvers/sundials.pyx:2112, in assimulo.solvers.sundials.CVode.integrate()
#
# File assimulo/solvers/sundials.pyx:2201, in assimulo.solvers.sundials.CVode.integrate()
#
# CVodeError: 'Convergence test failures occurred too many times during one internal time step or minimum step size was reached. At time 138.526374.'

# %% [markdown]
# ## Pam Fig

# %%
from pam_fig import create_pam_fig

fig, axs = create_pam_fig(
    model=m,
    pfd_str=pfd_str,
    flourescence_str=flourescence_str,
    npq_str=None
)

axs["Fluo"].text(0.5, 1.1, file_append, ha='center', va='bottom', transform=axs["Fluo"].transAxes)

plt.savefig(f"{file_prepend}/pam_fig/{file_append}.png", dpi=300, bbox_inches='tight');
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## FvCB

# %%
from inject_fvcb import create_fvcb_fig

fig, ax = create_fvcb_fig(
    model=m,
    pfd=pfd_str,
    co2=co2_str,
    vc=vc_str,
    pco2=pco2_str,
    H_cp_co2=H_cp_co2_str,
    gammastar=gammastar_str,
    r_light=r_light_str,
    A=A_str
)

ax.set_title(file_append)

plt.savefig(f"{file_prepend}/fvcb/{file_append}.png", dpi=300, bbox_inches='tight')
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 34.00it/s]
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## MCA

# %%
from photosynthesis_mca import create_mca_fig

fig, ax = create_mca_fig(
    model=m,
    coeff_psii=coeff_psii_str,
    coeff_psi=coeff_psi_str,
    coeff_rubisco=coeff_rubisco_str,
    coeff_cytb6f=coeff_cytb6f_str,
    coeff_atp_synthase=coeff_atp_synthase_str,
    rubp=rubp_str,
    co2=co2_str,
    pq=pq_str,
    pc=pc_str,
    atp=atp_str,
    nadph=nadph_str,
    v_rubisco=vc_str,
    v_psii=v_psii_str,
    v_psi=v_psi_str,
    v_cytb6f=v_cytb6f_str,
    v_atp_synthase=v_atp_synthase_str,
)

fig.suptitle(file_append)

plt.savefig(f"{file_prepend}/mca/{file_append}.png", dpi=300, bbox_inches='tight')
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Fitting

# %%
from utils import find_params_to_fit_byelasticities, find_params_to_fit_byorder

find_params_to_fit_byorder(
    to_fit_str=flourescence_str,
    model=m,
)
# Out:
# 100%|██████████| 167/167 [00:00<00:00, 176.02it/s]
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
find_params_to_fit_byelasticities(
    to_fit_str=n.fluorescence(),
    model=m,
    omit_strs=["pH", "T", "R", "F", "E^0_PQ", "E^0_QA", "HPR", "PSII_total", "LHC_tot"]
)
# Out:
# 100%|██████████| 167/167 [00:00<00:00, 178.11it/s]
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from fitting import create_pamfit

create_pamfit(
    model=m,
    pfd_str=pfd_str,
    flourescence_str=flourescence_str,
    pam_params_to_fit=["ksat_violaxanthin_deepoxidase", "gamma0", "ksat_lhc_protonation"],
    relative=True,
    standard_scale=True
)

plt.savefig(f"{file_prepend}/fitting/{file_append}.png", dpi=300)
# Out:
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.902847771926 and h = 0.00405002942032856, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 683.895993026127 and h = 0.00483289600074798, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 988.880426252295 and h = 0.00410585008401577, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1049.86915404601 and h = 0.00378427761407259, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.907793854531 and h = 0.00405560051545046, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1110.85943937239 and h = 0.00387088164388984, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 988.88024349026 and h = 0.00456913088082999, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 805.920114007431 and h = 0.0062559945450592, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 683.895880018458 and h = 0.00506067147036054, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1049.86853168799 and h = 0.00437798856370638, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 927.886569750177 and h = 0.0061781234891487, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1232.82058910519 and h = 0.00302405044781128, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 927.893997196119 and h = 0.00388957378362491, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 683.895672349019 and h = 0.00501330508246187, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.902296784103 and h = 0.00498296857556761, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1232.82024176206 and h = 0.00329473877056928, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 927.888216145201 and h = 0.00442784857530343, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 447.95086146627 and h = 0.00465319958387377, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 927.898967231321 and h = 0.00507881184360281, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 143.911383120244 and h = 0.005067170746806, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1110.89087665744 and h = 0.00503094936299085, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 988.91126306967 and h = 0.00452513660108047, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 683.897096256852 and h = 0.00484505790144733, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 988.88249829877 and h = 0.00487702055842294, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1049.87371654747 and h = 0.0053681591911559, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1110.8625605873 and h = 0.00373707112351752, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 79.9651052272394 and h = 0.00373916245098661, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 927.894880230243 and h = 0.00506153400614581, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 927.895442524453 and h = 0.0048444677189264, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 326.021203945081 and h = 0.00433410010874591, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 988.882767602173 and h = 0.0041081223493864, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 927.895343629105 and h = 0.00511593732032825, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 206.764878181772 and h = 0.00648402718277958, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 683.895371220174 and h = 0.00589998605163259, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.904906812252 and h = 0.00486046099430333, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 145.091256895699 and h = 0.00581252636936372, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1049.86701817575 and h = 0.00371007359946594, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1110.85756760945 and h = 0.00429683672216793, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1110.86060531708 and h = 0.00384221479280666, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 268.005267405185 and h = 0.00510545891136209, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 683.895171421452 and h = 0.0045309940645905, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 988.88129141454 and h = 0.00511546782332063, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 683.897451744552 and h = 0.00365491424406387, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1110.85770730652 and h = 0.00400689704080211, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 927.890933930665 and h = 0.00447109209995727, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 744.933714089383 and h = 0.00593523095481539, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1110.85629201553 and h = 0.00502515057964395, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1049.867099963 and h = 0.0035960028362959, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.904460899455 and h = 0.00520595447086105, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1049.86671326127 and h = 0.0041546391906309, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 988.881837863095 and h = 0.00401925676212367, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.908051984133 and h = 0.00501444890150837, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 927.890235034157 and h = 0.00531723677078312, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1232.82128095416 and h = 0.00270273826500415, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 264.064804963041 and h = 0.00473622494566057, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1232.81969979691 and h = 0.00310058441683517, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.90389499224 and h = 0.00558282350982704, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.904148144387 and h = 0.00544922615841141, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 389.951786535959 and h = 0.00726845138590808, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.904460899455 and h = 0.00520595447086105, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.904460899455 and h = 0.00520595447086105, the corrector convergence test failed repeatedly or with |h| = hmin.
# {'ksat_violaxanthin_deepoxidase': 5.613273500889613, 'gamma0': 0.09843548320455198, 'ksat_lhc_protonation': 5.816954960013977}
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.904460899455 and h = 0.00520595447086105, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.902847771926 and h = 0.00405002942032856, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 683.895993026127 and h = 0.00483289600074798, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 988.880426252295 and h = 0.00410585008401577, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1049.86915404601 and h = 0.00378427761407259, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.907793854531 and h = 0.00405560051545046, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1110.85943937239 and h = 0.00387088164388984, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 988.88024349026 and h = 0.00456913088082999, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 805.920114007431 and h = 0.0062559945450592, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 683.895880018458 and h = 0.00506067147036054, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1049.86853168799 and h = 0.00437798856370638, the corrector convergence test failed repeatedly or with |h| = hmin.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
