# %% [markdown]
# # Saadat validations

# %%
from mxlbricks import get_saadat2021
from mxlpy import units
import mxlbricks.names as n
import matplotlib.pyplot as plt

m = get_saadat2021()
m.update_reaction(n.rubisco_carboxylase(), unit=units.mmol / (units.liter * units.second)); # Add Vc unit mM/s
file_prepend = "presentation"  # Path to save figures
file_append = "saadat2021"  # Identifier for the model validation

# %%
pfd_str = n.pfd()
vc_str = n.rubisco_carboxylase()
atp_str = n.atp()
nadph_str = n.nadph()
flourescence_str = n.fluorescence()
co2_str = n.co2()
pco2_str = None
H_cp_co2_str = None
gammastar_str = None
r_light_str = None
A_str = None
coeff_psii_str = "k2"
coeff_psi_str = None
coeff_rubisco_str = n.kcat(n.rubisco_carboxylase())
coeff_cytb6f_str = n.kcat(n.b6f())
coeff_atp_synthase_str = n.kf(n.atp_synthase())
rubp_str = n.rubp()
pq_str = n.pq_ox()
pc_str = n.pc_ox()
v_psii_str = "PSII"
v_psi_str = "PSI"
v_cytb6f_str = n.b6f()
v_atp_synthase_str = n.atp_synthase()

# %%
n.kf(n.atp_synthase())
# Out:
# 'kf_atp_synthase'

# %% [markdown]
# ## Day simulation

# %%
from GreenSlothUtils.demonstration import create_day_simulation_fig

fig, ax = create_day_simulation_fig(
    model=m,
    pfd=pfd_str,
    vc=vc_str,
    atp=atp_str,
    nadph=nadph_str,
    fluorescence=flourescence_str
)

ax.set_title(file_append)

plt.savefig(f"{file_prepend}/day_simulation/{file_append}.png", dpi=300, bbox_inches='tight')
# Out:
# Trying simulation with 1200 time points per step.

# %% [markdown]
# ## Pam Fig

# %%
from pam_fig import create_pam_fig

fig, axs = create_pam_fig(
    model=m,
    pfd_str=pfd_str,
    flourescence_str=flourescence_str,
    npq_str=None
)

axs["Fluo"].text(0.5, 1.1, file_append, ha='center', va='bottom', transform=axs["Fluo"].transAxes)

plt.savefig(f"{file_prepend}/pam_fig/{file_append}.png", dpi=300, bbox_inches='tight');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 from pam_fig import create_pam_fig
# ----> 3 fig, axs = create_pam_fig(
#       4     model=m,
#       5     pfd_str=pfd_str,
#       6     flourescence_str=flourescence_str,
#       7     npq_str=None
#       8 )
#      10 axs["Fluo"].text(0.5, 1.1, file_append, ha='center', va='bottom', transform=axs["Fluo"].transAxes)
#      12 plt.savefig(f"{file_prepend}/pam_fig/{file_append}.png", dpi=300, bbox_inches='tight');
#
# File ~/Documents/GreenSloth/Validations/pam_fig.py:102, in create_pam_fig(model, pfd_str, flourescence_str, npq_str, dark_light, sat_pulse)
#      99 pam_prtc, shading = make_pam_protocol(pfd_str=pfd_str, dark_light=dark_light, pulse_intensity=sat_pulse)
#     101 # Simulate pam protocol
# --> 102 res = pam_sim(
#     103     fit_protocol=make_protocol(pam_prtc),
#     104     model=model,
#     105     pfd_str=pfd_str,
#     106     dark_pfd=dark_light,
#     107 )
#     109 if res is None:
#     110     return
#
# File ~/Documents/GreenSloth/Validations/utils.py:141, in pam_sim(fit_protocol, model, pfd_str, dark_adaptation_time, dark_pfd)
#     137     print("No result from dark simulation")
#     138     return None
# --> 141 dark_y0 = s.get_result().get_new_y0()
#     143 s.clear_results()
#     144 s.update_variables(dark_y0)
#
# AttributeError: 'Result' object has no attribute 'get_new_y0'

# %% [markdown]
# ## FvCB

# %%
from inject_fvcb import create_fvcb_fig

fig, ax = create_fvcb_fig(
    model=m,
    pfd=pfd_str,
    co2=co2_str,
    vc=vc_str,
    pco2=pco2_str,
    H_cp_co2=H_cp_co2_str,
    gammastar=gammastar_str,
    r_light=r_light_str,
    A=A_str
)

ax.set_title(file_append)

plt.savefig(f"{file_prepend}/fvcb/{file_append}.png", dpi=300, bbox_inches='tight')
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 34.00it/s]
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## MCA

# %%
from photosynthesis_mca import create_mca_fig

fig, ax = create_mca_fig(
    model=m,
    coeff_psii=coeff_psii_str,
    coeff_psi=coeff_psi_str,
    coeff_rubisco=coeff_rubisco_str,
    coeff_cytb6f=coeff_cytb6f_str,
    coeff_atp_synthase=coeff_atp_synthase_str,
    rubp=rubp_str,
    co2=co2_str,
    pq=pq_str,
    pc=pc_str,
    atp=atp_str,
    nadph=nadph_str,
    v_rubisco=vc_str,
    v_psii=v_psii_str,
    v_psi=v_psi_str,
    v_cytb6f=v_cytb6f_str,
    v_atp_synthase=v_atp_synthase_str,
)

fig.suptitle(file_append)

plt.savefig(f"{file_prepend}/mca/{file_append}.png", dpi=300, bbox_inches='tight')
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Fitting

# %%
from utils import find_params_to_fit_byelasticities, find_params_to_fit_byorder

find_params_to_fit_byorder(
    to_fit_str=flourescence_str,
    model=m,
)
# Out:
# 100%|██████████| 167/167 [00:00<00:00, 176.02it/s]
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
find_params_to_fit_byelasticities(
    to_fit_str=n.fluorescence(),
    model=m,
    omit_strs=["pH", "T", "R", "F", "E^0_PQ", "E^0_QA", "HPR", "PSII_total", "LHC_tot"]
)
# Out:
# 100%|██████████| 167/167 [00:00<00:00, 178.11it/s]
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from fitting import create_pamfit

create_pamfit(
    model=m,
    pfd_str=pfd_str,
    flourescence_str=flourescence_str,
    pam_params_to_fit=["ksat_violaxanthin_deepoxidase", "gamma0", "ksat_lhc_protonation"],
    relative=True,
    standard_scale=True
)

plt.savefig(f"{file_prepend}/fitting/{file_append}.png", dpi=300)
# Out:
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.902847771926 and h = 0.00405002942032856, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 683.895993026127 and h = 0.00483289600074798, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 988.880426252295 and h = 0.00410585008401577, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1049.86915404601 and h = 0.00378427761407259, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.907793854531 and h = 0.00405560051545046, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1110.85943937239 and h = 0.00387088164388984, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 988.88024349026 and h = 0.00456913088082999, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 805.920114007431 and h = 0.0062559945450592, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 683.895880018458 and h = 0.00506067147036054, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1049.86853168799 and h = 0.00437798856370638, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 927.886569750177 and h = 0.0061781234891487, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1232.82058910519 and h = 0.00302405044781128, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 927.893997196119 and h = 0.00388957378362491, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 683.895672349019 and h = 0.00501330508246187, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.902296784103 and h = 0.00498296857556761, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1232.82024176206 and h = 0.00329473877056928, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 927.888216145201 and h = 0.00442784857530343, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 447.95086146627 and h = 0.00465319958387377, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 927.898967231321 and h = 0.00507881184360281, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 143.911383120244 and h = 0.005067170746806, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1110.89087665744 and h = 0.00503094936299085, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 988.91126306967 and h = 0.00452513660108047, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 683.897096256852 and h = 0.00484505790144733, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 988.88249829877 and h = 0.00487702055842294, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1049.87371654747 and h = 0.0053681591911559, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1110.8625605873 and h = 0.00373707112351752, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 79.9651052272394 and h = 0.00373916245098661, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 927.894880230243 and h = 0.00506153400614581, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 927.895442524453 and h = 0.0048444677189264, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 326.021203945081 and h = 0.00433410010874591, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 988.882767602173 and h = 0.0041081223493864, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 927.895343629105 and h = 0.00511593732032825, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 206.764878181772 and h = 0.00648402718277958, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 683.895371220174 and h = 0.00589998605163259, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.904906812252 and h = 0.00486046099430333, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 145.091256895699 and h = 0.00581252636936372, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1049.86701817575 and h = 0.00371007359946594, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1110.85756760945 and h = 0.00429683672216793, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1110.86060531708 and h = 0.00384221479280666, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 268.005267405185 and h = 0.00510545891136209, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 683.895171421452 and h = 0.0045309940645905, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 988.88129141454 and h = 0.00511546782332063, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 683.897451744552 and h = 0.00365491424406387, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1110.85770730652 and h = 0.00400689704080211, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 927.890933930665 and h = 0.00447109209995727, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 744.933714089383 and h = 0.00593523095481539, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1110.85629201553 and h = 0.00502515057964395, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1049.867099963 and h = 0.0035960028362959, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.904460899455 and h = 0.00520595447086105, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1049.86671326127 and h = 0.0041546391906309, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 988.881837863095 and h = 0.00401925676212367, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.908051984133 and h = 0.00501444890150837, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 927.890235034157 and h = 0.00531723677078312, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1232.82128095416 and h = 0.00270273826500415, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 264.064804963041 and h = 0.00473622494566057, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1232.81969979691 and h = 0.00310058441683517, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.90389499224 and h = 0.00558282350982704, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.904148144387 and h = 0.00544922615841141, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8097][cvHandleFailure] At t = 389.951786535959 and h = 0.00726845138590808, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.904460899455 and h = 0.00520595447086105, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.904460899455 and h = 0.00520595447086105, the corrector convergence test failed repeatedly or with |h| = hmin.
# {'ksat_violaxanthin_deepoxidase': 5.613273500889613, 'gamma0': 0.09843548320455198, 'ksat_lhc_protonation': 5.816954960013977}
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.904460899455 and h = 0.00520595447086105, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.902847771926 and h = 0.00405002942032856, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 683.895993026127 and h = 0.00483289600074798, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 988.880426252295 and h = 0.00410585008401577, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1049.86915404601 and h = 0.00378427761407259, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 866.907793854531 and h = 0.00405560051545046, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1110.85943937239 and h = 0.00387088164388984, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 988.88024349026 and h = 0.00456913088082999, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 805.920114007431 and h = 0.0062559945450592, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 683.895880018458 and h = 0.00506067147036054, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1744094662001/work/sundials/src/cvodes/cvodes.c:8101][cvHandleFailure] At t = 1049.86853168799 and h = 0.00437798856370638, the corrector convergence test failed repeatedly or with |h| = hmin.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
