# %%
from mxlpy import Simulator, make_protocol, plot
import itertools as it
from typing import cast, Literal
from tqdm.notebook import tqdm
from scipy.signal import find_peaks, peak_prominences
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.patches import Rectangle
import matplotlib.gridspec as gridspec
from matplotlib.lines import Line2D
import pandas as pd
import sqlite3
from pathlib import Path
import numpy as np
import sys

here = Path("").absolute()
print(here)
# Out:
# /home/elouen/Documents/GreenSloth/models/Li2021/paper_figures

# %%
module_path = Path("").absolute().parent
if module_path not in sys.path:
    sys.path.append(str(module_path))

# %%
from model import Li2021

# %%
NPQs = []

fig, ax = plt.subplots()

for pfd in [100, 500]:
    s = Simulator(Li2021())
    s.update_parameter('PAR', pfd)
    s.simulate(25*60)
    variables, fluxes = s.get_result()
    ax.plot(variables["NPQ"])

ax.set_xticks([i * 60 for i in np.arange(0, 30, 5)], [i for i in np.arange(0, 30, 5)])

plt.show()
