# %%
import matplotlib.pyplot as plt
import numpy as np
from model import get_model, pH, rev_pH, Keq_func, quadratic, get_quasi_model
from model.simulations import iterable_steady_scan_params, iterable_resp_coef_scan_params, simulate_to_steady_state_with_results, find_intersections, take_closest

from tqdm import tqdm
from modelbase2 import Model, Simulator, plot, mca
from concurrent import futures
import pandas as pd

from modelbase2.types import ArrayLike
from functools import partial

# %% [markdown]
# ## Get Model and test basic functions

# %%
m = get_model()

m.get_stoichiometries()

m.get_variable_names()
m.get_derived_variable_names()
# Out:
# ['N0', 'A3', 'PQ_red', 'ADP_st', 'Keq']

# %%
m.get_fluxes()
# Out:
# v1    1.666667e+01
# v2    4.250000e+06
# v3    0.000000e+00
# v4    0.000000e+00
# v5    2.560000e+03
# v6    5.001685e-11
# v7    0.000000e+00
# v8    0.000000e+00
# v9    0.000000e+00
# dtype: float64

# %% [markdown]
# ### Basic Plotting of basic simulation to test if any errors persist

# %%
s = Simulator(m)
s.update_parameter("PFD", 1000)
s.simulate(100)
concs = s.get_concs()

if concs is not None:
    fig, ax = plot.lines(concs)
    
    ax.set(xlabel="Time / a.u.", ylabel="Concentration / a.u.")
    
    plt.show

# %% [markdown]
# ## Figure 4

# %%
from assimulo.problem import Explicit_Problem
from assimulo.solvers import CVode

def el_simulate(
    m: Model,
    t_end,
    y0: ArrayLike = None,
):
    
    if y0 is None:
        y0 = m.get_initial_conditions()
        y0 = [y0[k] for k in m.get_variable_names()]
    
    intergrator = CVode(Explicit_Problem(m, y0), display_progress = False)
    
    time, results = intergrator.simulate(t_end)
    
    return pd.DataFrame(results, index=time, columns=m.get_variable_names())

def el_simulate_to_steady_state(
    m: Model,
    y0: ArrayLike = None,
    tolerance: float = 1e-8
):
    
    for t_end in np.geomspace(10, 1e9, 5):
        concs = el_simulate(m, t_end, y0)
        
        if concs is None:
            continue
        diff = concs.iloc[-1] - concs.iloc[-2]
        if np.linalg.norm(diff, ord=2) < tolerance:
            res =  concs.iloc[-1].to_dict()
            break
        
    if res is None:
        _ = dict()
        for i in m.get_variable_names():
            _[i] = None
            
        return _
    else:
        return res

def change_parameter_for_steady_state_scan(
    param_val,
    param_str,
    m,
    y0 = None,
    tolerance = 1e-8
):
    m.update_parameter(param_str, param_val)
    return el_simulate_to_steady_state(m, y0, tolerance)

def iterable_steady_state_scan(
    m: Model,
    param_str: str,
    param_vals,
):
    fn = partial(change_parameter_for_steady_state_scan,
        m = m,
        param_str = param_str,
    )
    
    with futures.ProcessPoolExecutor() as ex:
        return pd.DataFrame(tqdm(ex.map(fn, param_vals), desc = "Steady-State Scan", total = len(param_vals)), index=param_vals)
    
scan = iterable_steady_state_scan(
get_model(),
param_str = 'PFD',
param_vals = np.linspace(1e-4, 2000, 100)
)
# Out:
# Steady-State Scan:   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/elouen/Documents/PhotoModelBase/models/Ebenhoeh2011/.pixi/envs/default/lib/python3.13/concurrent/futures/process.py", line 254, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
#   File "/home/elouen/Documents/PhotoModelBase/models/Ebenhoeh2011/.pixi/envs/default/lib/python3.13/concurrent/futures/process.py", line 203, in _process_chunk
#     return [fn(*args) for args in chunk]
#             ~~^^^^^^^
#   File "/tmp/ipykernel_31834/1471054111.py", line 53, in change_parameter_for_steady_state_scan
#     return el_simulate_to_steady_state(m, y0, tolerance)
#   File "/tmp/ipykernel_31834/1471054111.py", line 27, in el_simulate_to_steady_state
#     concs = el_simulate(m, t_end, y0)
#   File "/tmp/ipykernel_31834/1471054111.py", line 14, in el_simulate
#     intergrator = CVode(Explicit_Problem(m, y0), display_progress = False)
#   File "assimulo/solvers/sundials.pyx", line 1546, in assimulo.solvers.sundials.CVode.__init__
# TypeError: __init__() got an unexpected keyword argument 'display_progress'
# """
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 68
#      65     with futures.ProcessPoolExecutor() as ex:
#      66         return pd.DataFrame(tqdm(ex.map(fn, param_vals), desc = "Steady-State Scan", total = len(param_vals)), index=param_vals)
# ---> 68 scan = iterable_steady_state_scan(
#      69 get_model(),
#      70 param_str = 'PFD',
#      71 param_vals = np.linspace(1e-4, 2000, 100)
#      72 )
#
# Cell In[28], line 66, in iterable_steady_state_scan(m, param_str, param_vals)
#      60 fn = partial(change_parameter_for_steady_state_scan,
#      61     m = m,
#      62     param_str = param_str,
#      63 )
#      65 with futures.ProcessPoolExecutor() as ex:
# ---> 66     return pd.DataFrame(tqdm(ex.map(fn, param_vals), desc = "Steady-State Scan", total = len(param_vals)), index=param_vals)
#
# File ~/Documents/PhotoModelBase/models/Ebenhoeh2011/.pixi/envs/default/lib/python3.13/site-packages/pandas/core/frame.py:843, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     841         data = np.asarray(data)
#     842     else:
# --> 843         data = list(data)
#     844 if len(data) > 0:
#     845     if is_dataclass(data[0]):
#
# File ~/Documents/PhotoModelBase/models/Ebenhoeh2011/.pixi/envs/default/lib/python3.13/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/Documents/PhotoModelBase/models/Ebenhoeh2011/.pixi/envs/default/lib/python3.13/concurrent/futures/process.py:617, in _chain_from_iterable_of_lists(iterable)
#     611 def _chain_from_iterable_of_lists(iterable):
#     612     """
#     613     Specialized implementation of itertools.chain.from_iterable.
#     614     Each item in *iterable* should be a list.  This function is
#     615     careful not to keep references to yielded objects.
#     616     """
# --> 617     for element in iterable:
#     618         element.reverse()
#     619         while element:
#
# File ~/Documents/PhotoModelBase/models/Ebenhoeh2011/.pixi/envs/default/lib/python3.13/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/Documents/PhotoModelBase/models/Ebenhoeh2011/.pixi/envs/default/lib/python3.13/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~/Documents/PhotoModelBase/models/Ebenhoeh2011/.pixi/envs/default/lib/python3.13/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/Documents/PhotoModelBase/models/Ebenhoeh2011/.pixi/envs/default/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# TypeError: __init__() got an unexpected keyword argument 'display_progress'

# %%
s = Simulator(get_model(), simulation_parameters = [{"atol": 1e-12}])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 s = Simulator(get_model(), simulation_parameters = [{"atol": 1e-12}])
#
# TypeError: Simulator.__init__() got an unexpected keyword argument 'simulation_parameters'

# %%
#Get steady state solutions for variable PFD values
scan = iterable_steady_scan_params(
    get_model(),
    param_str = 'PFD',
    param_vals = np.linspace(1e-4, 2000, 100)
)

# Get response coefficients (D, PQ_tot, k5, k9) for variable PFD values
mca_scan = iterable_resp_coef_scan_params(
    m = get_model(),
    param_str = 'PFD',
    param_vals = np.linspace(1e-4, 2000, 100),
    params_to_extract = ["D", "PQ_tot", "k5", "k9"]
)

fig, axs = plt.subplots(3, 2, figsize = (10, 5))

# Plot Lumen pH against PFD
axs[0, 0].plot(scan.index, pH(scan["H_lu"]), color = '#232021')
# Plot Quencher (N) against PFD
axs[1, 0].plot(scan.index, scan["N"], color = '#232021')
# Plot Relative ATP against PFD
axs[2, 0].plot(scan.index, scan["ATP_st"] / get_model().parameters['AP_tot'], color = '#232021')

# Plot all three response coefficient plots
color_dict = {
    'D': '#323784',
    'PQ_tot': '#00ab4e',
    'k5': '#f15221',
    'k9': '#00aba2'
}

for param, color in color_dict.items():
    axs[0, 1].plot(mca_scan.concs.index, [i.loc['H_lu'][param] for i in mca_scan.concs], color = color, label = param, lw = 2)
    axs[1, 1].plot(mca_scan.index, [i.loc['N'][param] for i in mca_scan.concs], color = color, label = param, lw = 2)
    axs[2, 1].plot(mca_scan.index, [i.loc['ATP_st'][param] for i in mca_scan.concs], color = color, label = param, lw = 2)

# Stylings
axs[0, 0].set_yticks([6, 6.5, 7])
axs[0, 0].set_ylim(6, 7)
axs[0, 0].set_ylabel('pH')
axs[0, 0].set_title('steady state variables depending on light intensity', size = '11')

axs[1, 0].set_yticks([0, 0.5, 1])
axs[1, 0].set_ylim(0, 1)
axs[1, 0].set_ylabel('quenching, N')

axs[2, 0].set_yticks([0, 0.5, 1])
axs[2, 0].set_ylim(0, 1)
axs[2, 0].set_ylabel('ATP (relative)')
axs[2, 0].set_xlabel(r"light intensity, $\mathrm{\mu E\ m}^{-2}\ \mathrm{s}^{-1}$")

axs[0, 1].set_ylim(-0.5, 0.5)
axs[0, 1].set_yticks([-0.5, 0, 0.5])
axs[0, 1].set_ylabel('pH')
axs[0, 1].set_title('response coefficients', size = '11')

axs[1, 1].set_ylim(-1, 1)
axs[1, 1].set_ylabel('quenching, N')

axs[2, 1].set_ylim(-1, 1)
axs[2, 1].set_ylabel('ATP')
axs[2, 1].set_xlabel(r"light intensity, $\mathrm{\mu E\ m}^{-2}\ \mathrm{s}^{-1}$")

# All xticks
for ax_row in axs:
    for ax in ax_row:
        ax.set_xticks([0, 500, 1000, 1500, 2000])
        ax.set_xlim(0, 2000)
        ax.tick_params(
            axis = 'both',
            direction = 'in',
            top = True,
            right = True
        )

# Legend
axs[0, 1].legend(
    loc = 'upper left',
    bbox_to_anchor = (1, 1.06),
    fancybox = False,
    framealpha = 1,
    edgecolor = '#242122'
)

plt.tight_layout()
plt.show()
# Out:
# Steady-State Scan:  33%|███▎      | 33/100 [00:01<00:03, 21.26it/s]RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 5.41644 and h = 0.33971, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 3.77288 and h = 0.239915, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 6.84763 and h = 0.53362, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 9.06072 and h = 0.226731, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 8.27391 and h = 0.298504, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  39%|███▉      | 39/100 [00:02<00:03, 19.05it/s]RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 5.36526 and h = 0.358841, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 9.63701 and h = 0.362989, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8028][cvHandleFailure] At t = 0.115948 and h = 6.4419e-05, the error test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 11.9699 and h = 0.354125, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 12.5866 and h = 0.0776289, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 12.898 and h = 0.382768, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 13.4842 and h = 0.256209, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  42%|████▏     | 42/100 [00:02<00:04, 12.95it/s][ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 9.46407 and h = 0.599122, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 13.9992 and h = 0.192902, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 14.7657 and h = 0.539374, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 14.4302 and h = 0.301927, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8028][cvHandleFailure] At t = 0.0789875 and h = 6.6145e-05, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 8.30191 and h = 0.503748, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 12.4979 and h = 0.192529, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  44%|████▍     | 44/100 [00:02<00:06,  9.33it/s]RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 15.4695 and h = 0.327221, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 16.3951 and h = 0.3809, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 14.9912 and h = 0.298255, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 16.7714 and h = 0.343089, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 17.0284 and h = 0.353887, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 8.39364 and h = 0.164877, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 17.6653 and h = 0.410881, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 12.4975 and h = 0.326497, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 15.4776 and h = 0.206116, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 16.3758 and h = 0.132309, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 16.6095 and h = 0.360415, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 14.9505 and h = 0.315202, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 18.3329 and h = 0.257881, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 17.5738 and h = 0.182418, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 18.6516 and h = 0.325866, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 8.39364 and h = 0.164877, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  47%|████▋     | 47/100 [00:04<00:11,  4.79it/s]RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 12.4975 and h = 0.326497, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 19.5824 and h = 0.122801, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 20.334 and h = 0.218175, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 15.1933 and h = 0.478878, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 16.2548 and h = 0.278164, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 16.4645 and h = 0.491769, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 14.9505 and h = 0.315202, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  59%|█████▉    | 59/100 [00:04<00:03, 10.43it/s]RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 20.662 and h = 0.175876, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 17.625 and h = 0.21383, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 18.4706 and h = 0.203236, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 18.7049 and h = 0.349216, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 21.3503 and h = 0.283111, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 20.1382 and h = 0.358398, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 21.7535 and h = 0.330877, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 16.4645 and h = 0.491769, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 16.2548 and h = 0.278164, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 15.1933 and h = 0.478878, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  61%|██████    | 61/100 [00:05<00:04,  8.32it/s][ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 22.0786 and h = 0.108755, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 17.625 and h = 0.21383, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  65%|██████▌   | 65/100 [00:05<00:03, 10.15it/s][ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 20.6152 and h = 0.294985, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 22.9519 and h = 0.24999, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 18.438 and h = 0.232174, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 18.664 and h = 0.320434, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 23.3767 and h = 0.163109, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 20.3565 and h = 0.189147, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 21.4702 and h = 0.383277, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 23.596 and h = 0.320889, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 22.056 and h = 0.201235, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 24.0169 and h = 0.30855, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 24.4319 and h = 0.343498, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 24.3552 and h = 0.110802, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 20.2861 and h = 0.525093, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 18.438 and h = 0.232174, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 23.031 and h = 0.2429, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  67%|██████▋   | 67/100 [00:06<00:04,  6.96it/s]RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 18.664 and h = 0.320434, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 24.9282 and h = 0.312908, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 25.1911 and h = 0.45721, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 23.3352 and h = 0.401957, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 21.7501 and h = 0.0970441, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 25.352 and h = 0.344303, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 20.3565 and h = 0.189147, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  72%|███████▏  | 72/100 [00:06<00:03,  8.81it/s][ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 23.3837 and h = 0.505725, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 24.0039 and h = 0.231014, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 22.1082 and h = 0.330803, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 25.8584 and h = 0.148127, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 24.6325 and h = 0.3422, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 23.0837 and h = 0.178267, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 20.2861 and h = 0.525093, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  74%|███████▍  | 74/100 [00:06<00:03,  7.89it/s][ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 21.7501 and h = 0.0970441, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  76%|███████▌  | 76/100 [00:07<00:02,  8.05it/s]RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 23.3769 and h = 0.168359, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 26.6811 and h = 0.29238, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 25.384 and h = 0.281616, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 24.0096 and h = 0.147444, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 23.5105 and h = 0.38628, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 24.5154 and h = 0.224925, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 23.0837 and h = 0.178267, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 22.1082 and h = 0.330803, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  78%|███████▊  | 78/100 [00:07<00:02,  7.39it/s]RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 25.7982 and h = 0.346407, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 26.8695 and h = 0.354607, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.0116 and h = 0.334134, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.6984 and h = 0.192928, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 26.6937 and h = 0.117524, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.7224 and h = 0.499345, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.5037 and h = 0.107346, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 23.3769 and h = 0.168359, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  81%|████████  | 81/100 [00:07<00:02,  7.60it/s][ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 25.4928 and h = 0.387159, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 24.0096 and h = 0.147444, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 24.5154 and h = 0.224925, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 26.8609 and h = 0.274778, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 23.5105 and h = 0.38628, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  82%|████████▏ | 82/100 [00:07<00:02,  7.45it/s]RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.0516 and h = 0.390258, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 25.6901 and h = 0.345157, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.4467 and h = 0.287475, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.2342 and h = 0.117495, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.5289 and h = 0.356088, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.0627 and h = 0.110205, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.5882 and h = 0.324231, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 26.6427 and h = 0.41197, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.5195 and h = 0.178509, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 25.4928 and h = 0.387159, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  88%|████████▊ | 88/100 [00:08<00:01,  9.09it/s][ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.2803 and h = 0.0677918, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 25.6901 and h = 0.345157, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.0634 and h = 0.337837, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 26.6427 and h = 0.41197, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  92%|█████████▏| 92/100 [00:08<00:00, 11.19it/s][ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.6326 and h = 0.299935, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.5161 and h = 0.330907, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.2803 and h = 0.0677918, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  94%|█████████▍| 94/100 [00:08<00:00, 11.64it/s][ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.0634 and h = 0.337837, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.6326 and h = 0.299935, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  96%|█████████▌| 96/100 [00:08<00:00, 11.87it/s][ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.5161 and h = 0.330907, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan: 100%|██████████| 100/100 [00:08<00:00, 11.14it/s]
# Response Coefficient Scan:  28%|██▊       | 28/100 [00:22<00:44,  1.61it/s][ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 5.34508 and h = 0.338961, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 6.25695 and h = 0.346477, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 5.19439 and h = 0.515609, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 8.10354 and h = 0.435499, the corrector convergence test failed repeatedly or with |h| = hmin.
# Response Coefficient Scan:  31%|███       | 31/100 [00:24<00:42,  1.61it/s]RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 8.22244 and h = 0.546331, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 7.46396 and h = 0.445556, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 6.87743 and h = 0.298931, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 7.62407 and h = 0.247871, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 8.96953 and h = 0.314525, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 8.83139 and h = 0.548152, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 8.33819 and h = 0.665754, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 6.13404 and h = 0.358916, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 6.97911 and h = 0.209781, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 5.45625 and h = 0.255795, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 8.44724 and h = 0.134634, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 9.09594 and h = 0.313287, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 8.04864 and h = 0.502375, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 9.07935 and h = 0.0941575, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 7.64297 and h = 0.271193, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 6.92592 and h = 0.269004, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 5.36526 and h = 0.358841, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 7.54629 and h = 0.824063, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8028][cvHandleFailure] At t = 0.115948 and h = 6.4419e-05, the error test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 5.36526 and h = 0.358841, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 8.2857 and h = 0.234386, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 6.77322 and h = 0.53631, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 8.79111 and h = 0.480548, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8028][cvHandleFailure] At t = 0.115948 and h = 6.4419e-05, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 5.18805 and h = 0.531029, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 6.92732 and h = 0.426771, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 8.94106 and h = 0.416167, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 5.93103 and h = 0.494122, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 8.04429 and h = 0.556073, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 7.48422 and h = 0.48418, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 6.18774 and h = 0.29188, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 9.06636 and h = 0.273608, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 6.84171 and h = 0.377022, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 4.24737 and h = 0.64865, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 7.48422 and h = 0.48418, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 5.35004 and h = 0.417661, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 6.29565 and h = 0.356527, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 5.36526 and h = 0.358841, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8028][cvHandleFailure] At t = 0.115948 and h = 6.4419e-05, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8028][cvHandleFailure] At t = 0.166906 and h = 7.37206e-05, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 5.93103 and h = 0.494122, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 7.68739 and h = 0.222927, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8028][cvHandleFailure] At t = 0.166906 and h = 7.37206e-05, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8028][cvHandleFailure] At t = 0.166906 and h = 7.37206e-05, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 6.96521 and h = 0.510457, the corrector convergence test failed repeatedly or with |h| = hmin.
# ...
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 26.773 and h = 0.304798, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 26.5581 and h = 0.299042, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.2287 and h = 0.230894, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.2916 and h = 0.238339, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 25.0493 and h = 0.300591, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 25.4973 and h = 0.282212, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8028][cvHandleFailure] At t = 0.103887 and h = 4.64314e-05, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.5255 and h = 0.333053, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.567 and h = 0.15119, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.2287 and h = 0.230894, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.5778 and h = 0.350773, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 26.773 and h = 0.304798, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.2287 and h = 0.230894, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.7587 and h = 0.181042, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.2705 and h = 0.376383, the corrector convergence test failed repeatedly or with |h| = hmin.
# Response Coefficient Scan:  86%|████████▌ | 86/100 [01:00<00:11,  1.21it/s][ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.7823 and h = 0.298559, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.7227 and h = 0.285378, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.0792 and h = 0.206189, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 26.3103 and h = 0.33276, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.7227 and h = 0.285378, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.4708 and h = 0.287247, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 25.6881 and h = 0.347539, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.2909 and h = 0.241588, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.7227 and h = 0.285378, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.1502 and h = 0.380107, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.9644 and h = 0.352186, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.1252 and h = 0.334035, the corrector convergence test failed repeatedly or with |h| = hmin.
# Response Coefficient Scan:  89%|████████▉ | 89/100 [01:01<00:05,  1.95it/s]RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 26.3103 and h = 0.33276, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.2287 and h = 0.230894, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.2705 and h = 0.376383, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# Response Coefficient Scan:  94%|█████████▍| 94/100 [01:01<00:01,  3.65it/s]RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.1963 and h = 0.706618, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.9465 and h = 0.354754, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.3104 and h = 0.143819, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.1963 and h = 0.706618, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.9873 and h = 0.24056, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.2705 and h = 0.376383, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.1963 and h = 0.706618, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.7347 and h = 0.295342, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.4873 and h = 0.225691, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.7227 and h = 0.285378, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.1252 and h = 0.334035, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.9465 and h = 0.354754, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.1252 and h = 0.334035, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.2705 and h = 0.376383, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.8903 and h = 0.125172, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.9465 and h = 0.354754, the corrector convergence test failed repeatedly or with |h| = hmin.
# Response Coefficient Scan:  96%|█████████▌| 96/100 [01:01<00:01,  3.66it/s]RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.1252 and h = 0.334035, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.7347 and h = 0.295342, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.7347 and h = 0.295342, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.1963 and h = 0.706618, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.9465 and h = 0.354754, the corrector convergence test failed repeatedly or with |h| = hmin.
# Response Coefficient Scan:  97%|█████████▋| 97/100 [01:02<00:00,  3.77it/s]RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.7347 and h = 0.295342, the corrector convergence test failed repeatedly or with |h| = hmin.
# Response Coefficient Scan: 100%|██████████| 100/100 [01:02<00:00,  1.60it/s]

# %%
m = get_model()

for i in np.linspace(1e-4, 2000, 100):
    
    m.update_parameter('PFD', i)

    s = Simulator(m)

    rel_norm = False
    tolerance = 1e-8
    try:
        for t_end in np.geomspace(10, 1e9, 5):
            s.simulate(t_end)
            y = s.get_concs()
            diff = (y.iloc[-1] - y.iloc[-2]) / y.iloc[-1] if rel_norm else y.iloc[-1] - y.iloc[-2]
            if np.linalg.norm(diff, ord=2) < tolerance:
                t_, y_ = t_end, y.iloc[-2]
                break
    except:
        t_, y_ = None, None
# Out:
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 3.77288 and h = 0.239915, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 5.41644 and h = 0.33971, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 6.84763 and h = 0.53362, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 8.27391 and h = 0.298504, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 9.06072 and h = 0.226731, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 9.63701 and h = 0.362989, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 11.9699 and h = 0.354125, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 12.5866 and h = 0.0776289, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 12.898 and h = 0.382768, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 13.4842 and h = 0.256209, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 13.9992 and h = 0.192902, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 14.4302 and h = 0.301927, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 14.7657 and h = 0.539374, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 15.4695 and h = 0.327221, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 16.3951 and h = 0.3809, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 16.7714 and h = 0.343089, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 17.0284 and h = 0.353887, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 17.6653 and h = 0.410881, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 18.3329 and h = 0.257881, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 18.6516 and h = 0.325866, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 19.5824 and h = 0.122801, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 20.334 and h = 0.218175, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 20.662 and h = 0.175876, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 21.3503 and h = 0.283111, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 21.7535 and h = 0.330877, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 22.0786 and h = 0.108755, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 22.9519 and h = 0.24999, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 23.3767 and h = 0.163109, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 23.596 and h = 0.320889, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 24.0169 and h = 0.30855, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 24.3552 and h = 0.110802, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 24.4319 and h = 0.343498, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 24.9282 and h = 0.312908, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 25.1911 and h = 0.45721, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 25.352 and h = 0.344303, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 25.8584 and h = 0.148127, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 26.6811 and h = 0.29238, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 26.8695 and h = 0.354607, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.0116 and h = 0.334134, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.5037 and h = 0.107346, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.6984 and h = 0.192928, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.7224 and h = 0.499345, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.0516 and h = 0.390258, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.4467 and h = 0.287475, the corrector convergence test failed repeatedly or with |h| = hmin.

# %%
y_
# Out:
# A1         1.659940
# A2         0.000184
# PQ_ox     12.538838
# H_lu       0.003041
# N          0.716733
# ATP_st    20.151384
# Name: 1000.0, dtype: float64

# %% [markdown]
# ## Figure 5

# %%
#Get steady state solutions for variable PFD values
scan = iterable_steady_scan_params(
    get_model(),
    param_str = 'PFD',
    param_vals = np.linspace(1e-4, 2000, 100)
)

fig, ax = plt.subplots()

# Plot steady state solutions for variable PFD values (black line)
ax.plot(scan["N"], pH(scan["H_lu"]), c="k", zorder = 5)

# Style Dictionary for easier styling
style_dict = {
    '600': {
        'Marker': '.'
    },
    '800': {
        'Marker': '+'
    },
    '1000': {
        'Marker': 'x'
    },
    '1200': {
        'Marker': 's'
    },
}

t = tqdm(style_dict.items(), total = len(style_dict.keys()))
for pfd, style in t:
    t.set_description(f"Calculating for PFD {pfd}")
    # Run Simulations for dark to light
    s = Simulator(get_model())
    
    s.update_parameter("PFD", int(pfd))
    
    simulate_to_steady_state_with_results(s = s)

    res_dtl = s.get_full_concs()
    plt.plot(res_dtl["N"], pH(res_dtl["H_lu"]), c="#ef481e")
    
    # Create List of times and results that are near to 1s Intervalls
    time = res_dtl.index
    marker_times = [take_closest(time, i) for i in range(0, int(time[-1] + 1))]
    marker_res = res_dtl.loc[marker_times]
    plt.plot(marker_res["N"], pH(marker_res["H_lu"]), label = pfd, c = "#ef481e", marker = style['Marker'], lw = 0)
    
    # Interpolate results to find intersections with steady-state scan
    xx, interp_res = find_intersections (
        scan["N"],
        pH(scan['H_lu']),
        res_dtl["N"],
        pH(res_dtl["H_lu"])
    )
    
    ax.plot(xx, interp_res,
             marker = 'o', fillstyle = "none", markeredgewidth = 3, markersize = 15,
             c = '#ef481e',
             zorder = 3, )
    
    # Simulate from light to dark
    y0_new = s.get_new_y0()
    s.clear_results()
    s.y0 = y0_new
    s.update_parameter("PFD", get_model().get_args()['PFD'])
    
    simulate_to_steady_state_with_results(s = s)
    res_ltd = s.get_full_concs()
    plt.plot(res_ltd["N"], pH(res_ltd["H_lu"]), c="#28338d")
    
# Finishing Style
ax.legend()
ax.set_xlabel("quenching activity, N")
ax.set_ylabel("lumen pH")
ax.set_xlim(0, 0.8)
ax.set_xticks([0, 0.2, 0.4, 0.6, 0.8])
ax.set_ylim(3, 7)
ax.set_yticks([3, 4, 5, 6, 7])

plt.tight_layout()
plt.show()

s.simulate_to_steady_state()
# Out:
# Steady-State Scan:  30%|███       | 30/100 [00:01<00:02, 24.39it/s][ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8028][cvHandleFailure] At t = 0.166906 and h = 7.37206e-05, the error test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 5.36526 and h = 0.358841, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8028][cvHandleFailure] At t = 0.115948 and h = 6.4419e-05, the error test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  33%|███▎      | 33/100 [00:01<00:03, 17.23it/s]RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 5.93103 and h = 0.494122, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 7.48422 and h = 0.48418, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  36%|███▌      | 36/100 [00:01<00:03, 19.04it/s]RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 9.46407 and h = 0.599122, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  39%|███▉      | 39/100 [00:02<00:03, 17.70it/s]RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 10.0491 and h = 0.458093, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 10.8793 and h = 0.231084, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 12.9489 and h = 0.249446, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 12.5647 and h = 0.155875, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 11.4315 and h = 0.183089, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 13.9551 and h = 0.324842, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  48%|████▊     | 48/100 [00:02<00:02, 24.85it/s]RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 14.4235 and h = 0.382423, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 13.4023 and h = 0.327744, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 16.2066 and h = 0.286102, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 14.7463 and h = 0.413925, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 16.7413 and h = 0.196778, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 17.2042 and h = 0.308401, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 18.0049 and h = 0.297464, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 17.6018 and h = 0.2462, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  53%|█████▎    | 53/100 [00:02<00:02, 20.93it/s]RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 18.3377 and h = 0.248291, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 19.0559 and h = 0.376082, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 20.2619 and h = 0.252981, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  61%|██████    | 61/100 [00:02<00:01, 26.18it/s]RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 19.4481 and h = 0.391962, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 21.073 and h = 0.368195, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 21.4328 and h = 0.150087, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 21.7456 and h = 0.633742, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 21.7681 and h = 0.278644, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  68%|██████▊   | 68/100 [00:03<00:01, 26.10it/s]RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 22.5504 and h = 0.479892, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 23.0669 and h = 0.164057, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 23.6345 and h = 0.390647, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 23.4301 and h = 0.361554, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 23.988 and h = 0.168621, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 24.5299 and h = 0.338537, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  73%|███████▎  | 73/100 [00:03<00:01, 23.95it/s]RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8028][cvHandleFailure] At t = 0.103887 and h = 4.64314e-05, the error test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 25.4973 and h = 0.282212, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 25.0493 and h = 0.300591, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 25.6881 and h = 0.347539, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  84%|████████▍ | 84/100 [00:03<00:00, 34.06it/s]RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 26.5581 and h = 0.299042, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 26.3103 and h = 0.33276, the corrector convergence test failed repeatedly or with |h| = hmin.
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.2705 and h = 0.376383, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 26.773 and h = 0.304798, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.7227 and h = 0.285378, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.9465 and h = 0.354754, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 27.2287 and h = 0.230894, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan:  94%|█████████▍| 94/100 [00:03<00:00, 41.93it/s]RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# RuntimeWarning: invalid value encountered in log10
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.1963 and h = 0.706618, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.7347 and h = 0.295342, the corrector convergence test failed repeatedly or with |h| = hmin.
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 28.1252 and h = 0.334035, the corrector convergence test failed repeatedly or with |h| = hmin.
# Steady-State Scan: 100%|██████████| 100/100 [00:03<00:00, 27.14it/s]
# Calculating for PFD 1000:  50%|█████     | 2/4 [00:01<00:01,  1.92it/s]RuntimeWarning: invalid value encountered in log10
# Calculating for PFD 1000:  50%|█████     | 2/4 [00:01<00:01,  1.62it/s]
# [ERROR][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:8032][cvHandleFailure] At t = 10.1548 and h = 0.641424, the corrector convergence test failed repeatedly or with |h| = hmin.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 40
#      37 simulate_to_steady_state_with_results(s = s)
#      39 res_dtl = s.get_full_concs()
# ---> 40 plt.plot(res_dtl["N"], pH(res_dtl["H_lu"]), c="#ef481e")
#      42 # Create List of times and results that are near to 1s Intervalls
#      43 time = res_dtl.index
#
# TypeError: 'NoneType' object is not subscriptable

# %%
def simulate_PAM(
    m: Model,
    actinic_light: float = 0,
    actinic_light_start: float = 100,
    actinic_light_end: float = 400 + 100/3,
    start_PAM: float = 0,
    end_PAM: float = 800,
    sp_step: float = 100 / 3,
    sp_pfd: float = 4000
):
    s = Simulator(m)
    s.update_parameter("PFD", 0)
    s.initialise(y0)
    
    for step in tqdm(np.arange(start_PAM, end_PAM, sp_step)):
        if step == 0:
            continue
        
        s.simulate(step - 1, atol=1e-12, rtol=1e-12)
        
        s.update_parameter("PFD", sp_pfd)
        s.simulate(step, atol=1e-12, rtol=1e-12)
        if step >= actinic_light_start and step < actinic_light_end:
            norm_pfd = actinic_light
        else:
            norm_pfd = 0
        s.update_parameter("PFD", norm_pfd)

    res = s.get_full_results_df()
    res = res.drop(0)
    res = res[res.index >= 1]
    flou = (1 - res["N"]) * res["A3"] / get_model().parameters["D"]
    rel_flou = flou - min(flou)
    rel_flou = flou / max(flou)
    
    return rel_flou

def create_figure7():
    fig, axs = plt.subplots(nrows = 3)
    
    actinic_lights = [300, 600, 1200]
    
    for i in tqdm(range(len(actinic_lights))):
        res = simulate_PAM(get_model(), actinic_lights[i])
        axs[i].plot(res,
                    color = "#f14e22"
                    )
        axs[i].set_ylim(0, 1)
        axs[i].set_yticks([0, 0.5, 1])
        axs[i].set_xlim(0, 700)
        axs[i].set_xticks(np.arange(0, 700 + 100, 100))
        axs[i].tick_params(
                axis = 'both',
                direction = 'in',
                top = True,
                right = True
            )
        # Actinic Light section styling
        x1 = 100
        x2 = 400 + 100 / 3
        height = 0.1
        y = 0.85
        
        axs[i].hlines(y, x1, x2, lw = 3, color = '#221f20')
        axs[i].vlines([x1, x2], y - height / 2, y + height / 2, lw = 3, color = '#221f20')
        axs[i].text(x = (x2 - x1) / 2 + x1, y = y - height / 2, s = fr'{actinic_lights[i]} $\mathrm{{\mu E\ m}}^{{-2}}\ \mathrm{{s}}^{{-1}}$', ha = 'center', va = 'top')
        
    axs[0].set_title("Simulated PAM curves")
    axs[1].set_ylabel("Flourescence (norm.)")
    axs[2].set_xlabel("time, s")
    
    return fig

fig = create_figure7()
plt.tight_layout()
plt.show()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 532.333 and h = 3.86926e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 532.333 and h = 3.86926e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 565.667 and h = 3.90654e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 565.667 and h = 3.90654e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 599 and h = 3.9537e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 599 and h = 3.9537e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 632.333 and h = 4.00812e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 632.333 and h = 4.00812e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 665.667 and h = 4.06794e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 665.667 and h = 4.06794e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 699 and h = 4.13179e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 699 and h = 4.13179e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 732.333 and h = 4.19864e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 732.333 and h = 4.19864e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 765.667 and h = 4.26771e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 765.667 and h = 4.26771e-14 are such that t + h = t on the next step. The solver will continue anyway.
# 100%|██████████| 24/24 [00:14<00:00,  1.62it/s]
#  33%|███▎      | 1/3 [00:14<00:29, 14.92s/it]
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 532.333 and h = 4.12582e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 532.333 and h = 4.12582e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 565.667 and h = 4.10873e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 565.667 and h = 4.10873e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 599 and h = 4.11558e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 599 and h = 4.11558e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 632.333 and h = 4.13925e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 632.333 and h = 4.13925e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 665.667 and h = 4.1751e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 665.667 and h = 4.1751e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 699 and h = 4.21995e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 699 and h = 4.21995e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 732.333 and h = 4.27155e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 732.333 and h = 4.27155e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 765.667 and h = 4.32825e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 765.667 and h = 4.32825e-14 are such that t + h = t on the next step. The solver will continue anyway.
# 100%|██████████| 24/24 [00:14<00:00,  1.70it/s]
#  67%|██████▋   | 2/3 [00:29<00:14, 14.50s/it]
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 532.333 and h = 4.39472e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 532.333 and h = 4.39472e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 565.667 and h = 4.31165e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 565.667 and h = 4.31165e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 599 and h = 4.27298e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 599 and h = 4.27298e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 632.333 and h = 4.26375e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 632.333 and h = 4.26375e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 665.667 and h = 4.275e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 665.667 and h = 4.275e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 699 and h = 4.30097e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 699 and h = 4.30097e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 732.333 and h = 4.33781e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 732.333 and h = 4.33781e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 765.667 and h = 4.38277e-14 are such that t + h = t on the next step. The solver will continue anyway.
# [WARNING][rank 0][/home/conda/feedstock_root/build_artifacts/sundials-split_1719462973569/work/sundials/src/cvodes/cvodes.c:3482][CVode] Internal t = 765.667 and h = 4.38277e-14 are such that t + h = t on the next step. The solver will continue anyway.
# 100%|██████████| 24/24 [00:13<00:00,  1.77it/s]
# 100%|██████████| 3/3 [00:42<00:00, 14.25s/it]

# %% [markdown]
# ### Figure 3

# %%
def constant_light(
    m: Model,
    pH_lumen: float,
    KQ: float = None,
    Keq: float = None,
):
    # Parameters
    params = m.get_all_parameters()
    
    k7 = params["k7"]
    k6 = params["k6"]
    n = params["n"]
    k5 = params["k5"]
    k9 = params["k9"]
    AP_tot = params["AP_tot"]
    k3p = params["k3p"]
    k4 = params["k4"]
    k1 = params["k1"]
    k2 = params["k2"]
    k3m = params["k3m"]
    D = params["D"]
    PQ_tot = params["PQ_tot"]

    if KQ is None:
        KQ = params["KQ"]
        
    H = rev_pH(pH_lumen)
    
    if Keq is None:
        Keq = Keq_func(
            H_lu = H,
            DG0 = params["DG0"],
            H_st = params["H_st"],
            RT = params["RT"],
            Pi = params["Pi"]
        )
        
    N = 1 / (1 + (k7 / k6) * (H**n + (KQ ** n) / (H ** n)))
    ATP_st = AP_tot / (1 + (1 / Keq) + (k5/k9))
    v5 = k5 * (AP_tot - ATP_st * (1 + 1 / Keq))
    
    f = 1 - N
    alpha = k3p * k4 * (1 / (f * k1) + 1 / k2)
    beta = k3m * k4 / (f * k1)

    PQ_ox = quadratic(
        a = alpha - beta,
        b = k3p * D - alpha * PQ_tot + 2 * beta * PQ_tot + k4,
        c = -beta * PQ_tot**2 - k4 * PQ_tot,
        option='max'
    )
    
    v2 = k4 * (PQ_tot - PQ_ox)
    
    
    return N, ATP_st, v5, v2

# %%
fig, axs = plt.subplots(nrows = 2)

style_dict = {
    "6": {
        'ls': 'solid'
    },
    '5.8': {
        'ls': 'dashed'
    },
    '6.2': {
        'ls': 'dashdot'
    }
}

step = 0.01
pH_lumen = np.arange(5, 7.5 + step, step)

for KQ_pH, style in style_dict.items():
    N, ATP_st, v5, v2 = constant_light(
        m = get_model(),
        pH_lumen = pH_lumen,
        KQ = rev_pH(float(KQ_pH))
    )
    axs[0].plot(pH_lumen, N, color = "#0f1211", ls = style['ls'], label = KQ_pH)
    axs[1].plot(pH_lumen, v5, color = "#301b84", ls = style['ls'])
    axs[1].plot(pH_lumen, v2, color = "#b6421a", ls = style['ls'])


plt.show()

# %%
m = get_model()

m.update_parameter("PFD", 800)

N = []

for pH_lumen in np.arange(5, 8, 0.5):
    print(pH_lumen)
    y0 = {
        "A1": m.parameters["D"] / 2,
        "A2": m.parameters["D"] / 2,
        "PQ_ox": 0,
        "H_lu": rev_pH(pH_lumen),
        "N": 0,
        "ATP_st": 0,
    }
    s = Simulator(m)
    s.initialise(y0)
    
    s.simulate(1000)
    res = s.get_fluxes_df()
    N.append(res['v4'].iloc[0] + res['v2'].iloc[0])
    
    
    
print(N)
# Out:
# 5.0
# 5.5
# 6.0
# 6.5
# 7.0
# 7.5
# [np.float64(4250000.0), np.float64(4250000.0), np.float64(4250000.0), np.float64(4250000.0), np.float64(4250000.0), np.float64(4250000.0)]
