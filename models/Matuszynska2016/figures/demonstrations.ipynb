# %%
import os
import sys
from pathlib import Path

import matplotlib.pyplot as plt
from GreenSlothUtils.demonstration import (
    create_day_simulation_fig,
    create_fvcb_fig,
    create_mca_fig,
    create_pam_fig,
    create_pamfit,
)

sys.path.append(os.path.abspath('..'))

from model import Matuszynska2016

    
def save_fig(fig_name: str) -> Path:
    here = Path("").absolute()
    name = "Matuszynska2016"
    plt.savefig(here / f"{name.lower()}_demon_{fig_name}.svg", format="svg", bbox_inches="tight")

# %% [markdown]
# # Str Dictionary

# %%
pfd_str = "pfd"
vc_str = None
atp_str = "ATP_st"
nadph_str = None
fluorescence_str = "Fluo"
co2_str = None
pco2_str = None
H_cp_co2_str = None
gammastar_str = None
r_light_str = None
A_str = None
tend_quasi= None
npq_str = None
coeff_psii_str = "k_P"
coeff_psi_str = None
coeff_rubisco_str = None
coeff_cytb6f_str = "k_Cytb6f"
coeff_atp_synthase_str = "k_ATPsynth"
rubp_str = None
pq_str = "PQ"
pc_str = None
v_psii_str = "v_PSII"
v_psi_str = None
v_cytb6f_str = "v_PQ"
v_atp_synthase_str = "v_ATPsynth"

# %% [markdown]
# # Day Simulation

# %%
create_day_simulation_fig(
    model=Matuszynska2016(),
    pfd=pfd_str,
    vc=vc_str,
    atp=atp_str,
    nadph=nadph_str,
    fluorescence=fluorescence_str,
)

save_fig("daysimulation")
# Out:
# Trying simulation with 100 time points per step.

# %% [markdown]
# # FvCB Comparision

# %%
m = Matuszynska2016()

create_fvcb_fig(
    model=m,
    pfd=pfd_str,
    co2=co2_str,
    vc=vc_str,
    pco2=pco2_str,
    H_cp_co2=H_cp_co2_str,
    gammastar=gammastar_str,
    r_light=r_light_str,
    A=A_str,
    tend_quasi=tend_quasi
)

save_fig("fvcb")

# %% [markdown]
# # PAM Sample

# %%
create_pam_fig(
    model=Matuszynska2016(),
    pfd_str=pfd_str,
    fluorescence_str=fluorescence_str,
    npq_str=npq_str,
)

save_fig("pam")
# Out:
# Trying pam-simulation with 100 time points per step.

# %% [markdown]
# # Photosynthesis MCA

# %%
create_mca_fig(
    model=Matuszynska2016(),
    coeff_psii=coeff_psii_str,
    coeff_psi=coeff_psi_str,
    coeff_rubisco=coeff_rubisco_str,
    coeff_cytb6f=coeff_cytb6f_str,
    coeff_atp_synthase=coeff_atp_synthase_str,
    rubp=rubp_str,
    co2=co2_str,
    pq=pq_str,
    pc=pc_str,
    atp=atp_str,
    nadph=nadph_str,
    v_rubisco=vc_str,
    v_psii=v_psii_str,
    v_psi=v_psi_str,
    v_cytb6f=v_cytb6f_str,
    v_atp_synthase=v_atp_synthase_str,
)

save_fig("mca")

# %% [markdown]
# # PAM Fitting

# %%
from GreenSlothUtils.demonstration.utils import find_params_to_fit_byorder

find_params_to_fit_byorder(
    to_fit_str=fluorescence_str,
    model=Matuszynska2016(),
)
# Out:
# 100%|██████████| 42/42 [00:01<00:00, 32.00it/s]

# %%
create_pamfit(
    model=Matuszynska2016(),
    pfd_str=pfd_str,
    fluorescence_str=fluorescence_str,
    npq_str=npq_str,
    pam_params_to_fit=["gamma_0", "gamma_1", "gamma_2", "gamma_3", "K_ZSat"]
)

save_fig("fitting")
# Out:
# Trying pam-simulation with 100 time points per step.
